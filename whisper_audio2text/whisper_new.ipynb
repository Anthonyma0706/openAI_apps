# %%
import sys
import warnings
import whisper
from pathlib import Path
import subprocess
import torch
import numpy as np
from IPython.display import display, Markdown

# %%
# Set up the device for running the model
device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)

# Model selection
Model = 'medium'  # Choose from available models ['tiny.en', 'tiny', 'base.en', 'base', 'small.en', 'small', 'medium.en', 'medium', 'large']
whisper_model = whisper.load_model(Model)

# Verify if the chosen model is available
if Model not in whisper.available_models():
    raise ValueError(f"{Model} model is not available. Choose from: {', '.join(whisper.available_models())}")
# Out:
# Using device: cuda:0
# /home/mahmoodlab8/anaconda3/envs/whisper/lib/python3.8/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11000). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# Path to the local video file
video_path = './input_videos/538_1700534265.mp4'

# Convert the video to audio using FFmpeg
audio_path = Path(video_path).with_suffix('.wav')
subprocess.run(["ffmpeg", "-i", str(video_path), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(audio_path)])

# Transcription settings
language = "Chinese" #"English"  # Language for transcription
verbose = 'Live transcription'  # Verbose mode
output_format = 'srt'  # Output format for the transcript
task = 'transcribe'  # Task type

# Transcription arguments
args = {
    'language': language,
    'verbose': verbose == 'Live transcription',
    'task': task,
    # Add other parameters as required
}

# Perform transcription
video_transcription = whisper.transcribe(
    whisper_model,
    str(audio_path),
    **args,
)

# # Save the transcription output
# whisper.utils.get_writer(
#     output_format=output_format,
#     output_dir=audio_path.parent
# )(
#     video_transcription,
#     str(audio_path.stem),
#     {
#         "max_line_width": 47, 
#         "max_line_count": 1,
#         "highlight_words": False
#     }
# )

# print("Transcription complete. Transcript saved in:", audio_path.parent)
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './input_videos/538_1700534265.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2023-11-21T02:31:36.000000Z
#     copyright       :
#     copyright-eng   :
#   Duration: 00:05:40.22, start: -0.001451, bitrate: 965 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 544x960, 904 kb/s, 29.89 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       creation_time   : 2023-11-21T02:31:36.000000Z
#       handler_name    : Core Media Video
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 56 kb/s (default)
#     Metadata:
#       creation_time   : 2023-11-21T02:31:36.000000Z
#       handler_name    : Core Media Audio
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'input_videos/538_1700534265.wav':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     copyright-eng   :
#     ICOP            :
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2023-11-21T02:31:36.000000Z
#       handler_name    : Core Media Audio
#       encoder         : Lavc57.107.100 pcm_s16le
# size=   10632kB time=00:05:40.21 bitrate= 256.0kbits/s speed=1.64e+03x
# video:0kB audio:10632kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000716%
# /home/mahmoodlab8/anaconda3/envs/whisper/lib/python3.8/site-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# [00:00.000 --> 00:03.000] 大家早上好
# [00:03.000 --> 00:07.000] 今天我给大家分享的内容是想给大家介绍一下
# [00:07.000 --> 00:13.000] 什么样的紫砂壶去配什么样的茶
# [00:13.000 --> 00:19.000] 也就是说如何选择紫砂壶与茶来进行搭配
# [00:19.000 --> 00:23.000] 那么我们知道紫砂壶的壶型是很多的
# [00:23.000 --> 00:27.000] 有这样的稍微身比较高的
# [04:16.000 --> 04:17.000] 我们选择什么样的壶
# [04:17.000 --> 04:19.000] 除了这些壶型以外
# [04:19.000 --> 04:20.000] 其实最重要的
# [04:20.000 --> 04:21.000] 选择紫砂壶
# [04:21.000 --> 04:23.000] 其实首先的是它的泥料
# [04:23.000 --> 04:27.000] 用泥料一定是要特别好的
# [04:27.000 --> 04:29.000] 我们说是陈斧有年份的
# [04:29.000 --> 04:30.000] 然后呢
# [04:30.000 --> 04:33.000] 泥质呢比较好的这样的紫砂原矿泥料
# [04:33.000 --> 04:34.000] 然后呢
# [04:34.000 --> 04:36.000] 再就是呢我们的做工
# [04:36.000 --> 04:38.000] 那它的工艺一定是烧成温度要比较
# [04:38.000 --> 04:40.000] 烧成温度要十度
# [04:40.000 --> 04:42.000] 如果烧成温度不够的情况下呢
# [04:42.000 --> 04:43.000] 那么茶呢
# [04:43.000 --> 04:46.000] 茶壶就会有一些杂质和杂味
# [04:46.000 --> 04:49.000] 所以呢就会影响我们泡茶的这种口感
# [04:49.000 --> 04:52.000] 那么我们大多数会在选择紫砂壶的时候
# [04:52.000 --> 04:54.000] 第一要选择泥料
# [04:54.000 --> 04:56.000] 第二呢要选择它的工艺
# [04:56.000 --> 04:57.000] 也就是说
# [04:57.000 --> 04:59.000] 不管是这个是谁在做的
# [04:59.000 --> 05:00.000] 是哪一个名家做的
# [05:00.000 --> 05:01.000] 最主要的是呢
# [05:01.000 --> 05:03.000] 这个壶它做好以后
# [05:03.000 --> 05:06.000] 它整个的出汤是要特别的顺畅的
# [05:06.000 --> 05:10.000] 它就保证了最好的这个茶的口感可以释出
# [05:10.000 --> 05:13.000] 那么有的时候你再好的一个壶
# [05:13.000 --> 05:15.000] 如果在泡的时候呢
# [05:15.000 --> 05:17.000] 你会发现它出汤非常不顺畅
# [05:17.000 --> 05:18.000] 那也就会
# [05:18.000 --> 05:21.000] 写到一个闷了茶的这个作用
# [05:21.000 --> 05:23.000] 所以有时候我们泡的茶
# [05:23.000 --> 05:27.000] 为什么会用了那样的紫砂壶呢
# [05:27.000 --> 05:29.000] 会大大的打折扣啊
# [05:29.000 --> 05:30.000] 这个口感
# [05:30.000 --> 05:31.000] 好
# [05:31.000 --> 05:32.000] 那么我们今天呢
# [05:32.000 --> 05:36.000] 要给大家介绍的这个紫砂壶的一些小知识呢
# [05:36.000 --> 05:38.000] 就先介绍到这

# %%
# Perform transcription
# video_transcription = whisper.transcribe(
#     whisper_model,
#     str(audio_path),
#     **args,
# )

# Extract only the text from the transcription result
transcript_text = '\n'.join(segment['text'] for segment in video_transcription['segments'])

# Define the path for the text-only transcript file
transcript_text_path = audio_path.parent / f"{audio_path.stem}_transcript.txt"

# Save the text-only transcript
with open(transcript_text_path, 'w') as file:
    file.write(transcript_text)

print("Transcription complete. Text-only transcript saved in:", transcript_text_path)
# Out:
# Transcription complete. Text-only transcript saved in: input_videos/538_1700534265_transcript.txt
